# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Tendréis que realizar gráficas para contestar a las siguientes preguntas:
#
# 1. ¿Cuántos tickets tenemos de cada tipo?

# %%
df_year = pd.read_csv("datos/df_yeaar.csv")
df_year.head()
# Out:
#    Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 0           0  GDDENR-5042564453  2016-07-13       1735.0        4.0
# 1           1  GDDENR-8042508060  2016-05-18       1566.0       10.0
# 2           2  GDDESR-1342539995  2016-06-18        569.0       29.0
# 3           3  GDDTSR-5942488006  2016-04-28        320.0       40.0
# 4           4  GDLEER-0042524120  2016-06-03       1842.0       31.0
#
#        categoría       tipo           severidad        prioridad  \
# 0  Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 1  Acceso&%Login   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 2        Sistema   Problema  0 - Sin Clasificar  0 - Sin Asignar
# 3        Sistema  Solicitud  0 - Sin Clasificar  0 - Sin Asignar
# 4       Software   Problema          2 - Normal  0 - Sin Asignar
#
#    días_resolución  satisfacción      semestre
# 0              0.0           5.0   2º semestre
# 1              0.0           5.0  1er semestre
# 2              3.0           5.0  1er semestre
# 3              9.0           5.0  1er semestre
# 4              0.0           5.0  1er semestre

# %%
df_tickets = pd.DataFrame(df_year['tipo'].value_counts().reset_index(''))
df_tickets
# Out:
#        index  tipo
# 0  Solicitud  9675
# 1   Problema  3264

# %%
plt.figure()
plt.bar(df_tickets["index"],df_tickets["tipo"])
plt.show()

# %% [markdown]
# 3. Filtrad los datos para quedarnos solo con los datos de la categoría "Software".
#
# - Dentro del conjunto de datos filtrado que acabamos de generar, realiza la mejor visualización para mostrar cuantos tickets tenemos de cada tipo que tenemos (Problema o Solicitud).

# %%
df_sof = df_year[df_year['categoría'] == 'Software']
df_sof
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 4               4  GDLEER-0042524120  2016-06-03       1842.0       31.0
# 5               5  GDLEER-0142608095  2016-08-26         59.0       20.0
# 6               6  GDLEER-0242564650  2016-07-13       1175.0       36.0
# 7               7  GDLEER-0542574815  2016-07-23        561.0       18.0
# 8               8  GDLEER-0842457219  2016-03-28         71.0       12.0
# ...           ...                ...         ...          ...        ...
# 12908       13020  TWREER-3542682716  2016-11-08        411.0       37.0
# 12910       13022  TWREER-4142552705  2016-07-01       1680.0       27.0
# 12922       13034  TWRTER-2042528927  2016-06-07        462.0       19.0
# 12924       13036  TWRTER-8742418826  2016-02-18        942.0       28.0
# 12925       13037  TWRTER-9542402645  2016-02-02        334.0       26.0
#
#       categoría       tipo   severidad        prioridad  días_resolución  \
# 4      Software   Problema  2 - Normal  0 - Sin Asignar              0.0
# 5      Software   Problema  2 - Normal  0 - Sin Asignar              1.0
# 6      Software   Problema  2 - Normal  0 - Sin Asignar              2.0
# 7      Software   Problema  2 - Normal  0 - Sin Asignar              5.0
# 8      Software   Problema  2 - Normal  0 - Sin Asignar              8.0
# ...         ...        ...         ...              ...              ...
# 12908  Software   Problema   1 - Menor         1 - Baja              5.0
# 12910  Software   Problema   3 - Mayor         1 - Baja              1.0
# 12922  Software  Solicitud   1 - Menor         1 - Baja             10.0
# 12924  Software  Solicitud   1 - Menor         1 - Baja              7.0
# 12925  Software  Solicitud   1 - Menor         1 - Baja              5.0
#
#        satisfacción      semestre
# 4               5.0  1er semestre
# 5               1.0   2º semestre
# 6               1.0   2º semestre
# 7               5.0   2º semestre
# 8               5.0  1er semestre
# ...             ...           ...
# 12908           5.0   2º semestre
# 12910           5.0   2º semestre
# 12922           4.0  1er semestre
# 12924           5.0  1er semestre
# 12925           5.0  1er semestre
#
# [2590 rows x 12 columns]

# %%
df_sof_def = pd.DataFrame(df_sof['tipo'].value_counts().reset_index() )
df_sof_def
# Out:
#        index  tipo
# 0  Solicitud  1932
# 1   Problema   658

# %%
plt.figure()

plt.barh(df_sof_def["index"],df_sof_def["tipo"], color = "grey")

plt.show()

# %%
df_sof.sample(10)
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 4022         4064  KDLTER-0942412287  2016-02-12        928.0       22.0
# 1521         1533  GHLTER-6242402965  2016-02-02       1856.0       29.0
# 436           444  GDLTET-2742689285  2016-11-15        858.0       22.0
# 9414         9494  SHREET-2742392833  2016-01-23        293.0       28.0
# 1646         1659  GHLTET-3742370184  2016-01-01         68.0       31.0
# 1576         1588  GHLTER-8542473824  2016-04-13       1642.0       38.0
# 1148         1159  GHLEER-9142574192  2016-07-23       1879.0       21.0
# 366           371  GDLTER-6442611063  2016-08-29        936.0       10.0
# 1477         1489  GHLTER-3442566565  2016-07-15       1966.0       45.0
# 10139       10227  SWLTER-2942401485  2016-02-01        628.0        4.0
#
#       categoría       tipo   severidad        prioridad  días_resolución  \
# 4022   Software  Solicitud  2 - Normal  0 - Sin Asignar              9.0
# 1521   Software  Solicitud  2 - Normal         3 - Alta              2.0
# 436    Software  Solicitud  2 - Normal  0 - Sin Asignar              8.0
# 9414   Software   Problema   1 - Menor         3 - Alta              0.0
# 1646   Software  Solicitud  2 - Normal         3 - Alta              7.0
# 1576   Software  Solicitud  2 - Normal         3 - Alta              5.0
# 1148   Software   Problema  2 - Normal         3 - Alta              1.0
# 366    Software  Solicitud  2 - Normal  0 - Sin Asignar              4.0
# 1477   Software  Solicitud  2 - Normal         3 - Alta              4.0
# 10139  Software  Solicitud  2 - Normal         1 - Baja              9.0
#
#        satisfacción      semestre
# 4022            2.0  1er semestre
# 1521            5.0  1er semestre
# 436             5.0   2º semestre
# 9414            5.0  1er semestre
# 1646            5.0  1er semestre
# 1576            5.0  1er semestre
# 1148            5.0   2º semestre
# 366             5.0   2º semestre
# 1477            1.0   2º semestre
# 10139           4.0  1er semestre

# %%
dias_sat = df_sof.loc[:,['días_resolución','satisfacción']]
dias_sat
# Out:
#        días_resolución  satisfacción
# 4                  0.0           5.0
# 5                  1.0           1.0
# 6                  2.0           1.0
# 7                  5.0           5.0
# 8                  8.0           5.0
# ...                ...           ...
# 12908              5.0           5.0
# 12910              1.0           5.0
# 12922             10.0           4.0
# 12924              7.0           5.0
# 12925              5.0           5.0
#
# [2590 rows x 2 columns]

# %% [markdown]
# - Usando el mismo conjunto de datos filtrado, ¿existe alguna relación entre la satisfacción y los días de resolución?. Poned los nombres de los ejes, siendo el eje x los "días de resolución" y el eje y la "satisfacción".

# %%
plt.figure()

plt.scatter(dias_sat["días_resolución"],dias_sat["satisfacción"])
plt.xlabel('días resolución')
plt.ylabel('satisfacción')

plt.show()

# %% [markdown]
# - Usando el mismo conjunto de datos filtrado, ¿cuál es la frecuencia de cada una de las satisfacciones que tenemos en el conjunto de datos?

# %%
plt.figure()

plt.hist(x = df_sof["días_resolución"], edgecolor = "black" )
plt.xlabel('días resolución')
plt.ylabel('satisfacción')

plt.show()

# %% [markdown]
# 4. En el ejercicio anterior hemos filtrado por "Software", realizar los mismos ejercicios que en el ejercicio 3, solo que en este caso filtrar por "Hardware"

# %%
df_har = df_year[df_year['categoría'] == 'Hardware']
df_har
# Out:
#        Unnamed: 0          id_ticket       fecha  id_empleado  id_agente  \
# 15             15  GDLEER-2342731423  2016-12-27        422.0       24.0
# 18             18  GDLEER-3042628638  2016-09-15       1863.0       46.0
# 25             25  GDLEER-3542665966  2016-10-22       1996.0       29.0
# 27             27  GDLEER-3742656857  2016-10-13       1025.0       18.0
# 28             28  GDLEER-4042683896  2016-11-09       1469.0       38.0
# ...           ...                ...         ...          ...        ...
# 12689       12799  TWLTER-9942724654  2016-12-20       1245.0       16.0
# 12692       12802  TWLTET-8342499857  2016-05-09       1045.0       28.0
# 12909       13021  TWREER-4142462018  2016-04-02        111.0       30.0
# 12923       13035  TWRTER-5042710887  2016-12-06       1098.0       38.0
# 12926       13038  TWRTER-9642514691  2016-05-24        909.0       16.0
#
#       categoría       tipo   severidad        prioridad  días_resolución  \
# 15     Hardware   Problema  2 - Normal  0 - Sin Asignar             10.0
# 18     Hardware   Problema  2 - Normal  0 - Sin Asignar              9.0
# 25     Hardware   Problema  2 - Normal  0 - Sin Asignar              5.0
# 27     Hardware   Problema  2 - Normal  0 - Sin Asignar              7.0
# 28     Hardware   Problema  2 - Normal  0 - Sin Asignar             13.0
# ...         ...        ...         ...              ...              ...
# 12689  Hardware  Solicitud  2 - Normal         1 - Baja              7.0
# 12692  Hardware  Solicitud  2 - Normal         1 - Baja             11.0
# 12909  Hardware   Problema   1 - Menor         1 - Baja             11.0
# 12923  Hardware  Solicitud   1 - Menor         1 - Baja             10.0
# 12926  Hardware  Solicitud   3 - Mayor         1 - Baja              7.0
#
#        satisfacción      semestre
# 15              5.0   2º semestre
# 18              5.0   2º semestre
# 25              5.0   2º semestre
# 27              5.0   2º semestre
# 28              5.0   2º semestre
# ...             ...           ...
# 12689           4.0   2º semestre
# 12692           4.0  1er semestre
# 12909           5.0  1er semestre
# 12923           4.0   2º semestre
# 12926           5.0  1er semestre
#
# [1256 rows x 12 columns]

# %%
df_har_def = pd.DataFrame(df_har['tipo'].value_counts().reset_index() )
df_har_def
# Out:
#        index  tipo
# 0  Solicitud   944
# 1   Problema   312

# %%
plt.figure()

plt.barh(df_har_def["index"],df_har_def["tipo"], color = "grey")

plt.show()

# %%
dias_sat_har = df_har.loc[:,['días_resolución','satisfacción']]
dias_sat_har
# Out:
#        días_resolución  satisfacción
# 15                10.0           5.0
# 18                 9.0           5.0
# 25                 5.0           5.0
# 27                 7.0           5.0
# 28                13.0           5.0
# ...                ...           ...
# 12689              7.0           4.0
# 12692             11.0           4.0
# 12909             11.0           5.0
# 12923             10.0           4.0
# 12926              7.0           5.0
#
# [1256 rows x 2 columns]

# %%
plt.figure() #relación entre resolución y satisfacción en Hardware

plt.scatter(dias_sat_har["días_resolución"],dias_sat_har["satisfacción"])
plt.xlabel('días resolución')
plt.ylabel('satisfacción')

plt.show()

# %%
plt.figure() #frecuencias de la satisfacción en relación a los días de resolución

plt.hist(x = df_har["días_resolución"], edgecolor = "black" )
plt.xlabel('días resolución')
plt.ylabel('satisfacción')

plt.show()

# %% [markdown]
#  El objetivo, hacer una comparación entre la categoría "Software" y "Hardware",

# %%
from pydataset import data
import numpy as np
from scipy import stats
import pandas as pd

# %% [markdown]
# 1. Buscar un conjunto de datos a analizar:
#
# - Se recomienda que el conjunto de datos a analizar tenga variables numéricas y categóricas. Ya que también se analizarán.

# %%
df_wine = pd.read_csv("datos/winequality-white.csv", sep=";", index_col=0) #puestos-empleados
df_wine.head(20)
# Out:
#                volatile acidity  citric acid  residual sugar  chlorides  \
# fixed acidity
# 7.0                        0.27         0.36           20.70      0.045
# 6.3                        0.30         0.34            1.60      0.049
# 8.1                        0.28         0.40            6.90      0.050
# 7.2                        0.23         0.32            8.50      0.058
# 7.2                        0.23         0.32            8.50      0.058
# 8.1                        0.28         0.40            6.90      0.050
# 6.2                        0.32         0.16            7.00      0.045
# 7.0                        0.27         0.36           20.70      0.045
# 6.3                        0.30         0.34            1.60      0.049
# 8.1                        0.22         0.43            1.50      0.044
# 8.1                        0.27         0.41            1.45      0.033
# 8.6                        0.23         0.40            4.20      0.035
# 7.9                        0.18         0.37            1.20      0.040
# 6.6                        0.16         0.40            1.50      0.044
# 8.3                        0.42         0.62           19.25      0.040
# 6.6                        0.17         0.38            1.50      0.032
# 6.3                        0.48         0.04            1.10      0.046
# 6.2                        0.66         0.48            1.20      0.029
# 7.4                        0.34         0.42            1.10      0.033
# 6.5                        0.31         0.14            7.50      0.044
#
#                free sulfur dioxide  total sulfur dioxide  density    pH  \
# fixed acidity
# 7.0                           45.0                 170.0   1.0010  3.00
# 6.3                           14.0                 132.0   0.9940  3.30
# 8.1                           30.0                  97.0   0.9951  3.26
# 7.2                           47.0                 186.0   0.9956  3.19
# 7.2                           47.0                 186.0   0.9956  3.19
# 8.1                           30.0                  97.0   0.9951  3.26
# 6.2                           30.0                 136.0   0.9949  3.18
# 7.0                           45.0                 170.0   1.0010  3.00
# 6.3                           14.0                 132.0   0.9940  3.30
# 8.1                           28.0                 129.0   0.9938  3.22
# 8.1                           11.0                  63.0   0.9908  2.99
# 8.6                           17.0                 109.0   0.9947  3.14
# 7.9                           16.0                  75.0   0.9920  3.18
# 6.6                           48.0                 143.0   0.9912  3.54
# 8.3                           41.0                 172.0   1.0002  2.98
# 6.6                           28.0                 112.0   0.9914  3.25
# 6.3                           30.0                  99.0   0.9928  3.24
# 6.2                           29.0                  75.0   0.9892  3.33
# 7.4                           17.0                 171.0   0.9917  3.12
# 6.5                           34.0                 133.0   0.9955  3.22
#
#                sulphates  alcohol  quality
# fixed acidity
# 7.0                 0.45      8.8        6
# 6.3                 0.49      9.5        6
# 8.1                 0.44     10.1        6
# 7.2                 0.40      9.9        6
# 7.2                 0.40      9.9        6
# 8.1                 0.44     10.1        6
# 6.2                 0.47      9.6        6
# 7.0                 0.45      8.8        6
# 6.3                 0.49      9.5        6
# 8.1                 0.45     11.0        6
# 8.1                 0.56     12.0        5
# 8.6                 0.53      9.7        5
# 7.9                 0.63     10.8        5
# 6.6                 0.52     12.4        7
# 8.3                 0.67      9.7        5
# 6.6                 0.55     11.4        7
# 6.3                 0.36      9.6        6
# 6.2                 0.39     12.8        8
# 7.4                 0.53     11.3        6
# 6.5                 0.50      9.5        5

# %% [markdown]
# 2. Extraer los siguentes estadísiticos del conjunto de datos para varias de las variables disponibles:
#
# - Media

# %% [markdown]
# - Desviación con respecto de la media

# %% [markdown]
# - Varianza

# %% [markdown]
# - Desviación típica

# %% [markdown]
# - Moda

# %% [markdown]
# - Mediana

# %% [markdown]
# - Media ponderada

# %% [markdown]
# - Robustez

# %% [markdown]
# - Coeficiente de variación

# %% [markdown]
# 3. Interpretación de los resultados.
#
# - Ahora interpreta los resultados obtenidos de los diferentes estadísticos estudiados haciendo hincapié en aspectos interesantes de tus datos y explica lo mejor posible la naturaleza de los mismos.
